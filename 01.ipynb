# %%
#similarity calculation

# %%
import cv2
import numpy as np

# Load image
img = cv2.imread('motion_paths02_torchid_osnet.png')

# Remove black background pixels
mask = np.any(img != [0, 0, 0], axis=-1)
colored_pixels = img[mask]

# Get unique colors
unique_colors = np.unique(colored_pixels.reshape(-1, 3), axis=0)

print(f"Number of unique colors: {len(unique_colors)}")
# print("Colors (BGR):")
# print(unique_colors)
# Out:
# Number of unique colors: 53
